# %% [markdown]
# # Lab4.1: Student Management System (List Operations)

# %%
# 1) เริ่มต้นด้วย list ว่างสำหรับเก็บชื่อนักศึกษา
student_names = []

# 2) เพิ่มนักศึกษา: รับชื่อจากผู้ใช้ 3 คน แล้ว append() เข้า list
print("\n[1] Add Students")
for i in range(3): #กำหนดตัวแปรใน loop 👈ต้องทำ
    name = input(f"Enter student name #{i + 1}: ") #กำหนดตัวแปร 👈ต้องทำ
    student_names.append(name)

print(f"Current list: {student_names}")

# 3) ค้นหานักศึกษา: ใช้ 'in' เพื่อเช็คว่ามีชื่อนี้อยู่ใน list หรือไม่
#    ถ้าพบ ให้แสดง index ด้วย index()
print("\n[2] Find a Student")
search_name = input("Enter a name to search for: ")

if search_name in student_names: #เขียนเงื่อนไข ถ้าหากมีชื่อในลิส: 👈ต้องทำ
    position = student_names.index(search_name)
    print(f"Found '{search_name}' at index {position}")
else:
    print(f"'{search_name}' not found in the list")

# 4) ลบนักศึกษา: เช็คก่อนว่ามีอยู่จริงหรือไม่ (กัน error) แล้วค่อย remove()
print("\n[3] Remove a Student")
remove_name = input("Enter a name to remove: ")

if remove_name in student_names:
    student_names.remove(remove_name) #เติมฟังก์ชัน remove(remove_name) 👈ต้องทำ
    print(f"'{remove_name}' has been removed")
else:
    print(f"'{remove_name}' not found, nothing removed")

print(f"Updated list: {student_names}")

# 5) เรียงลำดับรายชื่อตามตัวอักษรด้วย sort()
print("\n[4] Sort Students")
student_names.sort() #เติมฟังก์ชันsort()
print(f"Sorted list: {student_names}")

# 6) นับจำนวนนักศึกษาทั้งหมดด้วย len()
print("\n[5] Count Students")
print(f"Total students: {len(student_names)}") #ใช้คำสั่งlen() หาจำนวนนักศึกษาในลิส student_names👈ต้องทำ
# Out:
# [1] Add Students
# Current list: ['phongsakon', 'pokemon', 'naruto']
#
# [2] Find a Student
# Found 'phongsakon' at index 0
#
# [3] Remove a Student
# 'pokemon' has been removed
# Updated list: ['phongsakon', 'naruto']
#
# [4] Sort Students
# Sorted list: ['naruto', 'phongsakon']
#
# [5] Count Students
# Total students: 2

# %% [markdown]
# Challenge

# %%
 student_names = []
 student_ids = []
 while True:
    print("รายชื่อนักเรียนปัจจุบัน: \n", f"{"ชื่อ":<10} {"รหัส":<10}\n {'\n '.join([f'{name:<10} {id_:<10}' for name, id_ in zip(student_names, student_ids)])}", f"\nจำนวน: {len(student_names)} คน\n")
    print(" [1] เพิ่มนักเรียน \n [2] ค้นหานักเรียน \n [3] ลบนักเรียน \n [4] เรียงลำดับนักเรียน \n [5] ออกจากโปรแกรม \n")
    function = input(" เลือกฟังก์ชัน: ")
    if function == "1":
        name = input("ใส่ชื่อนักเรียนที่ต้องการเพิ่ม: ")
        id_ = input("ใส่รหัสนักเรียนที่ต้องการเพิ่ม: ")
        student_names.append(name)
        student_ids.append(id_)
        print(f"================\n'{name}' ถูกเพิ่มเรียบร้อยแล้ว \n================\n")
    elif function == "2":
        search_name = input("ใส่ชื่อนักเรียนที่ต้องการค้นหา: ")
        if search_name in student_names:
            position = student_names.index(search_name)
            print(f"================\nพบ '{search_name}' ในรายชื่อนักเรียน\n================")
        else:
            print(f"================\nไม่พบ '{search_name}' ในรายชื่อนักเรียน\n================")
    elif function == "3":
        remove_name = input("ใส่ชื่อนักเรียนที่ต้องการลบ: ")
        if remove_name in student_names:
            student_ids.remove(student_ids[student_names.index(remove_name)])
            student_names.remove(remove_name)
            print(f"================\n'{remove_name}' ถูกลบเรียบร้อยแล้ว\n================")
        else:
            print(f"================\nไม่พบ '{remove_name}' ในรายชื่อนักเรียน\n================")
    elif function == "4":
        combined = list(zip(student_names, student_ids))
        combined.sort()
        if combined:
            student_names, student_ids = map(list, zip(*combined))
        print("================\nรายชื่อนักเรียนถูกเรียงลำดับแล้ว\n================")
    elif function == "5":
        print("ออกจากโปรแกรม")
        break
    else:
        print("ฟังก์ชันไม่ถูกต้อง")
# Out:
# รายชื่อนักเรียนปัจจุบัน:
#  ชื่อ       รหัส
#
# จำนวน: 0 คน
#
#  [1] เพิ่มนักเรียน
#  [2] ค้นหานักเรียน
#  [3] ลบนักเรียน
#  [4] เรียงลำดับนักเรียน
#  [5] ออกจากโปรแกรม
#
# ...
# 'haimiya' ถูกเพิ่มเรียบร้อยแล้ว
# ...
#
# รายชื่อนักเรียนปัจจุบัน:
#  ชื่อ       รหัส
#  haimiya    663380676-7
# จำนวน: 1 คน
#
#  [1] เพิ่มนักเรียน
#  [2] ค้นหานักเรียน
#  [3] ลบนักเรียน
#  [4] เรียงลำดับนักเรียน
#  [5] ออกจากโปรแกรม
#
# ...
# 'ayano' ถูกเพิ่มเรียบร้อยแล้ว
# ...
#
# รายชื่อนักเรียนปัจจุบัน:
#  ชื่อ       รหัส
#  haimiya    663380676-7
#  ayano      663380777-7
# จำนวน: 2 คน
#
#  [1] เพิ่มนักเรียน
#  [2] ค้นหานักเรียน
#  [3] ลบนักเรียน
#  [4] เรียงลำดับนักเรียน
#  [5] ออกจากโปรแกรม
#
# ...
# 'phongsakon' ถูกเพิ่มเรียบร้อยแล้ว
# ...
#
# รายชื่อนักเรียนปัจจุบัน:
#  ชื่อ       รหัส
#  haimiya    663380676-7
#  ayano      663380777-7
#  phongsakon 663380282-7
# จำนวน: 3 คน
#
#  [1] เพิ่มนักเรียน
#  [2] ค้นหานักเรียน
#  [3] ลบนักเรียน
#  [4] เรียงลำดับนักเรียน
#  [5] ออกจากโปรแกรม
#
# ...
# พบ 'haimiya' ในรายชื่อนักเรียน
# ...

# %% [markdown]
# # Lab4.2: Geometric Calculations (Tuples & Immutability)

# %%
import math
# 1) กำหนดจุดสองจุดด้วย tuple: point1 และ point2
point1 = (6 ,  7) #เติมพิกัด x y ของจุด 👈ต้องทำ
point2 = (7, 6)  #เติมพิกัด x y ของจุด 👈ต้องทำ

# 2) เข้าถึงค่าพิกัด x, y ของแต่ละจุด
print("\n[1] Access Coordinates")
print(f"Point 1: x = {point1[0]}, y = {point1[1]}") #เติมเลข 0 และ 1 ใน [] 👈ต้องทำ
print(f"Point 2: x = {point2[0]}, y = {point2[1]}") #เติมเลข 0 และ 1 ใน [] 👈ต้องทำ

# 3) ทดลองแก้ไขค่าใน tuple เพื่อแสดงให้เห็นว่า tuple เปลี่ยนแปลงไม่ได้ (immutable)
print("\n[2] Attempt Modification (Immutability Demonstration)")
try:
    point1[0] = 5  # บรรทัดนี้จะทำให้เกิด TypeError เพราะ tuple แก้ไขไม่ได้
except TypeError as e:
    print(f"Error trying to modify tuple: {e}") 
print("#สาเหตุที่เกิด TypeError เพราะ tuple เป็น immutable คือ ไม่สามารถแก้ไขได้")
# 4) คำนวณระยะห่างระหว่างจุดสองจุดด้วยสูตรระยะทาง
#    distance = sqrt( (x2 - x1)^2 + (y2 - y1)^2 )
print("\n[3] Calculate Distance")
distance = math.sqrt((point2[0] - point1[0]) ** 2 + (point2[1] - point1[1]) ** 2) #เติมเลขตำแหน่งในลิส 0 และ 1 ใน [] ให้ถูกต้อง 👈ต้องทำ
print(f"Distance between point1 {point1} and point2 {point2}: {distance}")
# Out:
# [1] Access Coordinates
# Point 1: x = 6, y = 7
# Point 2: x = 7, y = 6
#
# [2] Attempt Modification (Immutability Demonstration)
# Error trying to modify tuple: 'tuple' object does not support item assignment
# #สาเหตุที่เกิด TypeError เพราะ tuple เป็น immutable คือ ไม่สามารถแก้ไขได้
#
# [3] Calculate Distance
# Distance between point1 (6, 7) and point2 (7, 6): 1.4142135623730951

# %% [markdown]
# Challenge

# %%
import matplotlib.pyplot as plt
import math
def calculate_distance(p1, p2):
    return math.sqrt((p2[0] - p1[0]) ** 2 + (p2[1] - p1[1]) ** 2)

point1 = input("ใส่พิกัด (x,y): ที่1 ")
point2 = input("ใส่พิกัด (x,y): ที่2 ")
point1 = tuple(map(int, point1.split(' ')))
point2 = tuple(map(int, point2.split(' ')))
distance = calculate_distance(point1, point2)
print(f"ระยะห่างระหว่าง {point1} และ {point2} คือ {distance}")

plt.figure(figsize=(5, 5))
plt.plot([point1[0], point2[0]], [point1[1], point2[1]], marker='o', linestyle='-', color='blue')
plt.scatter([point1[0], point2[0]], [point1[1], point2[1]], color='red', s=80)
plt.text(point1[0], point1[1], ' Point1', fontsize=10)
plt.text(point2[0], point2[1], ' Point2', fontsize=10)
plt.title('Plot of Two Points')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.axis('equal')
plt.show()
# Out:
# ระยะห่างระหว่าง (6, 7) และ (7, 6) คือ 1.4142135623730951

# %% [markdown]
# # Activity 4.1: List vs. Tuple: Scenario Matching

# %% [markdown]
# สิ่งที่อยากให้ทำ : สถานการณ์ต่อไปนี้ แต่ละเหตุการณ์ควรใช้ list หรือ tuple เพราะอะไร
#  1. ข้อมูลอุณหภูมิประจำวันที่มีการบันทึกไว้ตลอดหนึ่งสัปดาห์
#  * AWS list
#  2. ค่าสี RGB ของเฉดสีเฉพาะเฉดหนึ่ง (เช่น สีแดงคือ (255, 0, 0))
#  * AWS tuple
#  3. รายการสินค้าในรถเข็นชอปปิงที่สามารถกดเพิ่มหรือลบออกได้
#  * AWS list
#  4. รายชื่อวันในหนึ่งสัปดาห์เรียงตามลำดับ (จันทร์ - อาทิตย์)
#  * AWS tuple
#  5. คะแนนเก็บของนักเรียนจากการส่งงานชุดต่างๆ ซึ่งอาจมีการอัปเดตหรือแก้ไขคะแนนในภายหลังได้
#  * AWS list
#  6. พิกัด GPS ของสถานที่สำคัญหรือจุดแลนด์มาร์กที่ตั้งอยู่กับที่
#  * AWS tuple

# %% [markdown]
# # Activity 4.2: Interactive To-Do List (using List Operations)

# %% [markdown]
# สิ่งที่อยากให้ทำ : ให้นักเรียนพัฒนาโปรแกรมจัดการรายการสิ่งที่ต้องทำ (To-Do List) แบบข้อความ (Text-based) อย่างง่าย โดยประยุกต์ใช้ความรู้เรื่องการจัดการ List ที่ได้เรียนมา
# สิ่งที่ต้องมี
# 1. สร้าง List ว่างเริ่มต้นไว้ตัวหนึ่ง ชื่อว่า todo_list
# 2. ใช้การวนลูป while เพื่อแสดงเมนูคำสั่งให้ผู้ใช้เลือก ดังนี้:
# * 2.1  เพิ่มรายการงาน (Add a task)
# * 2.2  ดูรายการงานทั้งหมด (View tasks)
# * 2.3  ทำเครื่องหมายว่างานเสร็จสิ้นแล้ว (ลบงานออก โดยเลือกจากตำแหน่ง Index หรือตามชื่อคำสั่ง)
# * 2.4  ออกจากโปรแกรม (Exit)
# 3. ใช้คำสั่ง input() เพื่อรับค่าเมนูที่ผู้ใช้เลือก
# 4. ใช้คำสั่งจัดการ List ต่างๆ (เช่น append(), remove() หรือ pop(), len()) ในการบริหารจัดการข้อมูลใน todo_list

# %%
todo_list = []
while True:
    print("\n===== To-Do List =====")
    print("[1] เพิ่มรายการงาน")
    print("[2] ดูรายการงานทั้งหมด")
    print("[3] ลบรายการงาน")
    print("[4] ออกจากโปรแกรม")

    choice = input("เลือกเมนู: ").strip()

    if choice == "1":
        task = input("เพิ่มรายการงาน: ").strip()
        if task:
            todo_list.append(task)
            print(f"เพิ่ม '{task}' เรียบร้อยแล้ว")
        else:
            print("กรุณาใส่ชื่องานก่อน")

    elif choice == "2":
        if todo_list:
            print("รายการงานทั้งหมด:")
            for i, task in enumerate(todo_list, start=1):
                print(f"{i}. {task}")
        else:
            print("ยังไม่มีรายการงาน")

    elif choice == "3":
        if todo_list:
            print("รายการงานทั้งหมด:")
            for i, task in enumerate(todo_list, start=1):
                print(f"{i}. {task}")

            remove_choice = input("เลือกหมายเลขงานที่ต้องการลบ: ").strip()
            if remove_choice.isdigit():
                index = int(remove_choice) - 1
                if 0 <= index < len(todo_list):
                    removed_task = todo_list.pop(index)
                    print(f"ลบ '{removed_task}' เรียบร้อยแล้ว")
                else:
                    print("หมายเลขไม่ถูกต้อง")
            else:
                print("กรุณาใส่หมายเลข")
        else:
            print("ยังไม่มีรายการงานให้ลบ")

    elif choice == "4":
        print("ออกจากโปรแกรมแล้ว")
        break

    else:
        print("เมนูไม่ถูกต้อง กรุณาเลือกใหม่")
# Out:
# ===== To-Do List =====
# [1] เพิ่มรายการงาน
# [2] ดูรายการงานทั้งหมด
# [3] ลบรายการงาน
# [4] ออกจากโปรแกรม
# เพิ่ม 'clean house' เรียบร้อยแล้ว
#
# ===== To-Do List =====
# [1] เพิ่มรายการงาน
# [2] ดูรายการงานทั้งหมด
# [3] ลบรายการงาน
# [4] ออกจากโปรแกรม
# เพิ่ม 'play game' เรียบร้อยแล้ว
#
# ===== To-Do List =====
# [1] เพิ่มรายการงาน
# [2] ดูรายการงานทั้งหมด
# [3] ลบรายการงาน
# [4] ออกจากโปรแกรม
# รายการงานทั้งหมด:
# 1. clean house
# 2. play game
#
# ===== To-Do List =====
# [1] เพิ่มรายการงาน
# [2] ดูรายการงานทั้งหมด
# [3] ลบรายการงาน
# [4] ออกจากโปรแกรม
# รายการงานทั้งหมด:
# 1. clean house
# 2. play game
# ลบ 'clean house' เรียบร้อยแล้ว
#
# ===== To-Do List =====
# [1] เพิ่มรายการงาน
# [2] ดูรายการงานทั้งหมด
# [3] ลบรายการงาน
# [4] ออกจากโปรแกรม
# ออกจากโปรแกรมแล้ว
